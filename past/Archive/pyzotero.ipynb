# %%
from pyzotero import zotero
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
import os
import logging
from time import sleep
from datetime import datetime
from tqdm import tqdm  # For progress bars

class ZoteroGroupAnalyzer:
    def __init__(self):
        """Initialize the analyzer with specific Nechako group libraries using the local Zotero API."""
        self.libraries = {
            'portal': zotero.Zotero('364018', 'group', local=True),
            'search': zotero.Zotero('5494504', 'group', local=True)
        }
        
        # Set up logging with timestamps
        logging.basicConfig(
            level=logging.INFO,
            format='%(asctime)s - %(message)s',
            datefmt='%Y-%m-%d %H:%M:%S'
        )
        self.logger = logging.getLogger(__name__)
        
        # Verify connections and get total counts
        self.total_counts = {}
        for name, zot in self.libraries.items():
            try:
                items = zot.items(limit=1)
                total = zot.count_items()
                self.total_counts[name] = total
                self.logger.info(f"Connected to {name} library. Total items: {total}")
            except Exception as e:
                self.logger.error(f"Failed to connect to {name} library: {str(e)}")
                raise

    def get_all_items(self, zot, library_name):
        """Safely retrieve all items with detailed progress tracking."""
        all_items = []
        start = 0
        limit = 50
        total = self.total_counts[library_name]
        
        # Create progress bar
        with tqdm(total=total, desc=f"Retrieving {library_name} items") as pbar:
            while True:
                try:
                    self.logger.info(f"Fetching items {start}-{start+limit} of {total} from {library_name}")
                    items = zot.items(start=start, limit=limit)
                    if not items:
                        break
                    
                    all_items.extend(items)
                    items_added = len(items)
                    pbar.update(items_added)
                    
                    self.logger.info(f"Successfully retrieved {items_added} items from {library_name}")
                    start += limit
                    
                    if start >= total:
                        break
                    
                    sleep(0.5)  # Prevent overloading
                    
                except Exception as e:
                    self.logger.warning(f"Error retrieving items at offset {start}: {str(e)}")
                    if start > 0:  # If we've already gotten some items, return those
                        break
                    else:
                        raise
        
        self.logger.info(f"Completed retrieval for {library_name}. Got {len(all_items)} items")
        return all_items

    def extract_library_structure(self, library_name):
        """Extract complete structure with progress tracking."""
        zot = self.libraries[library_name]
        structure = {
            'collections': [],
            'items': [],
            'collection_items': []
        }
        
        try:
            # Get collections with progress tracking
            self.logger.info(f"Getting collections for {library_name}...")
            collections = zot.collections()
            self.logger.info(f"Found {len(collections)} collections in {library_name}")
            
            # Process collections with progress bar
            with tqdm(collections, desc=f"Processing {library_name} collections") as pbar:
                for coll in pbar:
                    structure['collections'].append({
                        'key': coll['key'],
                        'name': coll['data']['name'],
                        'parent': coll['data'].get('parentCollection', None)
                    })
                    
                    try:
                        items = zot.collection_items(coll['key'])
                        self.logger.info(f"Retrieved {len(items)} items from collection: {coll['data']['name']}")
                        for item in items:
                            structure['collection_items'].append({
                                'collection_key': coll['key'],
                                'item_key': item['key'],
                                'collection_name': coll['data']['name'],
                                'title': item['data'].get('title', ''),
                                'item_type': item['data'].get('itemType', '')
                            })
                    except Exception as e:
                        self.logger.warning(f"Error getting items for collection {coll['data']['name']}: {str(e)}")
            
            # Get all items using progress tracking
            self.logger.info(f"Starting retrieval of all items from {library_name}...")
            all_items = self.get_all_items(zot, library_name)
            structure['items'] = all_items
            
            return structure
            
        except Exception as e:
            self.logger.error(f"Error extracting structure from {library_name}: {str(e)}")
            raise

    def analyze_duplicates(self):
        """Compare libraries with progress tracking."""
        try:
            self.logger.info("Starting duplicate analysis...")
            
            # Get items from both libraries
            portal_items = {}
            search_items = {}
            
            for lib_name, items_dict in [('portal', portal_items), ('search', search_items)]:
                self.logger.info(f"Processing {lib_name} library for duplicates...")
                all_items = self.get_all_items(self.libraries[lib_name], lib_name)
                
                # Process items with progress bar
                with tqdm(all_items, desc=f"Processing {lib_name} titles") as pbar:
                    for item in pbar:
                        if 'title' in item['data']:
                            items_dict[item['data']['title'].lower()] = item
            
            # Find duplicates
            duplicate_titles = set(portal_items.keys()) & set(search_items.keys())
            self.logger.info(f"Found {len(duplicate_titles)} duplicate titles")
            
            # Create visualization
            self.logger.info("Creating Venn diagram...")
            plt.figure(figsize=(10, 10))
            venn2([set(portal_items.keys()), set(search_items.keys())],
                  set_labels=('Portal Library', 'Search Library'))
            plt.title('Library Content Overlap')
            plt.savefig('library_overlap.png')
            plt.close()
            
            # Process duplicates with progress bar
            duplicates_data = []
            with tqdm(duplicate_titles, desc="Processing duplicates") as pbar:
                for title in pbar:
                    duplicates_data.append({
                        'title': title,
                        'portal_id': portal_items[title]['key'] if title in portal_items else '',
                        'search_id': search_items[title]['key'] if title in search_items else '',
                        'item_type': portal_items[title]['data'].get('itemType', '') if title in portal_items else search_items[title]['data'].get('itemType', '')
                    })
            
            duplicates_df = pd.DataFrame(duplicates_data)
            
            return {
                'duplicates': duplicate_titles,
                'duplicates_df': duplicates_df,
                'stats': {
                    'portal_total': len(portal_items),
                    'search_total': len(search_items),
                    'duplicate_count': len(duplicate_titles)
                }
            }
            
        except Exception as e:
            self.logger.error(f"Error analyzing duplicates: {str(e)}")
            raise

    def export_analysis(self, output_dir='nechako_analysis'):
        """Export analysis with progress tracking."""
        try:
            os.makedirs(output_dir, exist_ok=True)
            self.logger.info(f"Created output directory: {output_dir}")
            
            # Process each library
            for lib_name in self.libraries:
                self.logger.info(f"\nStarting analysis of {lib_name} library...")
                structure = self.extract_library_structure(lib_name)
                
                # Export to Excel with progress updates
                excel_path = os.path.join(output_dir, f'{lib_name}_library_analysis.xlsx')
                self.logger.info(f"Exporting {lib_name} analysis to {excel_path}")
                
                with pd.ExcelWriter(excel_path) as writer:
                    # Collections
                    self.logger.info(f"Writing {len(structure['collections'])} collections...")
                    pd.DataFrame(structure['collections']).to_excel(writer, sheet_name='Collections', index=False)
                    
                    # Items
                    self.logger.info(f"Writing {len(structure['items'])} items...")
                    try:
                        items_df = pd.json_normalize([item['data'] for item in structure['items']])
                    except Exception as e:
                        self.logger.warning(f"Error normalizing items data: {str(e)}")
                        items_df = pd.DataFrame(structure['items'])
                    items_df.to_excel(writer, sheet_name='Items', index=False)
                    
                    # Collection items
                    self.logger.info(f"Writing {len(structure['collection_items'])} collection items...")
                    pd.DataFrame(structure['collection_items']).to_excel(writer, sheet_name='Collection_Items', index=False)
                
                self.logger.info(f"Completed export for {lib_name}")
            
            # Export duplicate analysis
            self.logger.info("\nPerforming duplicate analysis...")
            duplicate_analysis = self.analyze_duplicates()
            duplicate_path = os.path.join(output_dir, 'duplicate_analysis.xlsx')
            
            self.logger.info("Exporting duplicate analysis...")
            with pd.ExcelWriter(duplicate_path) as writer:
                pd.DataFrame([duplicate_analysis['stats']]).to_excel(writer, sheet_name='Summary', index=False)
                if 'duplicates_df' in duplicate_analysis:
                    duplicate_analysis['duplicates_df'].to_excel(writer, sheet_name='Detailed_Duplicates', index=False)
            
            self.logger.info(f"Analysis export completed. Files saved in: {output_dir}")
            
        except Exception as e:
            self.logger.error(f"Error exporting analysis: {str(e)}")
            raise

def main():
    start_time = datetime.now()
    print(f"Analysis started at: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")
    
    try:
        # Initialize analyzer
        analyzer = ZoteroGroupAnalyzer()
        
        # Export full analysis
        analyzer.export_analysis()
        
        # Print summary
        duplicate_analysis = analyzer.analyze_duplicates()
        print("\nAnalysis Summary:")
        print(f"Portal Library Items: {duplicate_analysis['stats']['portal_total']}")
        print(f"Search Library Items: {duplicate_analysis['stats']['search_total']}")
        print(f"Duplicate Items: {duplicate_analysis['stats']['duplicate_count']}")
        
        end_time = datetime.now()
        duration = end_time - start_time
        print(f"\nAnalysis completed at: {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
        print(f"Total duration: {duration}")
        
    except Exception as e:
        print(f"Error during analysis: {str(e)}")
        raise

if __name__ == "__main__":
    main()
# Out:
# INFO:__main__:Connected to portal library. Total items: 4789
# INFO:__main__:Connected to search library. Total items: 1316
# INFO:__main__:Created output directory: nechako_analysis
# INFO:__main__:
# Starting analysis of portal library...
# INFO:__main__:Getting collections for portal...
# INFO:__main__:Found 31 collections in portal
# Analysis started at: 2024-12-03 12:21:13
# Processing portal collections:   0%|          | 0/31 [00:00<?, ?it/s]INFO:__main__:Retrieved 0 items from collection: 1. Data Sources
# INFO:__main__:Retrieved 0 items from collection: Barry's Collection
# INFO:__main__:Retrieved 0 items from collection: Cheslatta
# INFO:__main__:Retrieved 0 items from collection: EDI
# INFO:__main__:Retrieved 100 items from collection: Large Lakes Monitoring
# INFO:__main__:Retrieved 0 items from collection: NWR
# INFO:__main__:Retrieved 0 items from collection: Saturation Search
# INFO:__main__:Retrieved 0 items from collection: 2. Team Work Folder
# INFO:__main__:Retrieved 0 items from collection: Christiana
# INFO:__main__:Retrieved 13 items from collection: Isla
# INFO:__main__:Retrieved 0 items from collection: Jonathan
# Processing portal collections:  35%|███▌      | 11/31 [00:00<00:00, 106.19it/s]INFO:__main__:Retrieved 79 items from collection: Sample 1 (Jan 10th, 2022)
# INFO:__main__:Retrieved 0 items from collection: Lisa
# INFO:__main__:Retrieved 9 items from collection: Margot
# INFO:__main__:Retrieved 100 items from collection: MP-JD Saturation Search (Journals only)
# INFO:__main__:Retrieved 1 items from collection: Scott
# INFO:__main__:Retrieved 2 items from collection: 3. Resources for Import
# INFO:__main__:Retrieved 3 items from collection: Climate Hope/Restoration resources for Import (Makayla)
# INFO:__main__:Retrieved 78 items from collection: Resources for Import (Christiana)
# INFO:__main__:Retrieved 76 items from collection: Resources for Import (Jonathan)
# INFO:__main__:Retrieved 8 items from collection: Resources for Import (Lisa)
# INFO:__main__:Retrieved 100 items from collection: 4. Uploaded Resources (in the Nechako Portal)
# Processing portal collections:  71%|███████   | 22/31 [00:00<00:00, 84.74it/s] INFO:__main__:Retrieved 56 items from collection: Subsurface papers
# INFO:__main__:Retrieved 78 items from collection: Books
# INFO:__main__:Retrieved 40 items from collection: IWRG paper
# INFO:__main__:Retrieved 1 items from collection: Movies
# INFO:__main__:Retrieved 100 items from collection: Nechako Archives
# INFO:__main__:Retrieved 100 items from collection: Nechako Lit Review Master List
# INFO:__main__:Retrieved 45 items from collection: Portal Resources
# INFO:__main__:Retrieved 5 items from collection: Reports
# INFO:__main__:Retrieved 2 items from collection: Websites
# Processing portal collections: 100%|██████████| 31/31 [00:00<00:00, 80.18it/s]
# INFO:__main__:Starting retrieval of all items from portal...
# Retrieving portal items:   0%|          | 0/4789 [00:00<?, ?it/s]INFO:__main__:Fetching items 0-50 of 4789 from portal
# INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 50-100 of 4789 from portal
# Retrieving portal items:   4%|▍         | 200/4789 [00:00<00:15, 298.57it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 100-150 of 4789 from portal
# Retrieving portal items:   6%|▋         | 300/4789 [00:01<00:19, 230.27it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 150-200 of 4789 from portal
# Retrieving portal items:   8%|▊         | 400/4789 [00:01<00:21, 205.79it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 200-250 of 4789 from portal
# Retrieving portal items:  10%|█         | 500/4789 [00:02<00:22, 193.01it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 250-300 of 4789 from portal
# Retrieving portal items:  13%|█▎        | 600/4789 [00:02<00:22, 187.05it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 300-350 of 4789 from portal
# Retrieving portal items:  15%|█▍        | 700/4789 [00:03<00:22, 182.47it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 350-400 of 4789 from portal
# Retrieving portal items:  17%|█▋        | 800/4789 [00:04<00:22, 179.07it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 400-450 of 4789 from portal
# Retrieving portal items:  19%|█▉        | 900/4789 [00:04<00:21, 176.94it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 450-500 of 4789 from portal
# Retrieving portal items:  21%|██        | 1000/4789 [00:05<00:21, 175.94it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 500-550 of 4789 from portal
# Retrieving portal items:  23%|██▎       | 1100/4789 [00:05<00:21, 175.28it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 550-600 of 4789 from portal
# Retrieving portal items:  25%|██▌       | 1200/4789 [00:06<00:20, 174.73it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 600-650 of 4789 from portal
# Retrieving portal items:  27%|██▋       | 1300/4789 [00:07<00:19, 174.56it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 650-700 of 4789 from portal
# Retrieving portal items:  29%|██▉       | 1400/4789 [00:07<00:19, 174.69it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 700-750 of 4789 from portal
# Retrieving portal items:  31%|███▏      | 1500/4789 [00:08<00:18, 174.73it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 750-800 of 4789 from portal
# Retrieving portal items:  33%|███▎      | 1600/4789 [00:08<00:18, 174.26it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 800-850 of 4789 from portal
# Retrieving portal items:  35%|███▌      | 1700/4789 [00:09<00:17, 174.33it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 850-900 of 4789 from portal
# Retrieving portal items:  38%|███▊      | 1800/4789 [00:09<00:17, 174.37it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 900-950 of 4789 from portal
# Retrieving portal items:  40%|███▉      | 1900/4789 [00:10<00:16, 173.51it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 950-1000 of 4789 from portal
# Retrieving portal items:  42%|████▏     | 2000/4789 [00:11<00:16, 173.91it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 
/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2350-2400 of 4789 from portal
# Retrieving portal items: 4800it [00:27, 174.60it/s]                          INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2400-2450 of 4789 from portal
# Retrieving portal items: 4900it [00:27, 173.49it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2450-2500 of 4789 from portal
# Retrieving portal items: 5000it [00:28, 173.72it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2500-2550 of 4789 from portal
# Retrieving portal items: 5100it [00:28, 173.63it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2550-2600 of 4789 from portal
# Retrieving portal items: 5200it [00:29, 173.53it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2600-2650 of 4789 from portal
# Retrieving portal items: 5300it [00:29, 173.38it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2650-2700 of 4789 from portal
# Retrieving portal items: 5400it [00:30, 173.53it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2700-2750 of 4789 from portal
# Retrieving portal items: 5500it [00:31, 173.93it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2750-2800 of 4789 from portal
# Retrieving portal items: 5600it [00:31, 174.39it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2800-2850 of 4789 from portal
# Retrieving portal items: 5700it [00:32, 175.23it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2850-2900 of 4789 from portal
# Retrieving portal items: 5800it [00:32, 175.41it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2900-2950 of 4789 from portal
# Retrieving portal items: 5900it [00:33, 175.80it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2950-3000 of 4789 from portal
# Retrieving portal items: 6000it [00:33, 176.37it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3000-3050 of 4789 from portal
# Retrieving portal items: 6100it [00:34, 175.64it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3050-3100 of 4789 from portal
# Retrieving portal items: 6200it [00:35, 175.22it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3100-3150 of 4789 from portal
# Retrieving portal items: 6300it [00:35, 175.78it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3150-3200 of 4789 from portal
# Retrieving portal items: 6400it [00:36, 176.10it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3200-3250 of 4789 from portal
# Retrieving portal items: 6500it [00:36, 175.98it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3250-3300 of 4789 from portal
# Retrieving portal items: 6600it [00:37, 176.08it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3300-3350 of 4789 from portal
# Retrieving portal items: 6700it [00:37, 175.68it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3350-3400 of 4789 from portal
# Retrieving portal items: 6800it [00:38, 175.37it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3400-3450 of 4789 from portal
# Retrieving portal items: 6900it [00:39, 175.79it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3450-3500 of 4789 from portal
# Retrieving portal items: 7000it [00:39, 175.55it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3500-3550 of 4789 from portal
# Retrieving portal items: 7100it [00:40, 176.17it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3550-3600 of 4789 from portal
# Retrieving portal items: 7200it [00:40, 175.78it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3600-3650 of 4789 from portal
# Retrieving portal items: 7300it [00:41, 175.04it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3650-3700 of 4789 from portal
# Retrieving portal items: 7400it [00:41, 174.68it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3700-3750 of 4789 from portal
# Retrieving portal items: 7500it [00:42, 175.78it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3750-3800 of 4789 from portal
# Retrieving portal items: 7600it [00:43, 175.06it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3800-3850 of 4789 from portal
# Retrieving portal items: 7700it [00:43, 174.28it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3850-3900 of 4789 from portal
# Retrieving portal items: 7800it [00:44, 174.07it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3900-3950 of 4789 from portal
# Retrieving portal items: 7900it [00:44, 173.76it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3950-4000 of 4789 from portal
# Retrieving portal items: 8000it [00:45, 173.41it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4000-4050 of 4789 from portal
# Retrieving portal items: 8100it [00:45, 173.63it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4050-4100 of 4789 from portal
# Retrieving portal items: 8200it [00:46, 173.29it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4100-4150 of 4789 from portal
# Retrieving portal items: 8300it [00:47, 173.26it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4150-4200 of 4789 from portal
# Retrieving portal items: 8400it [00:47, 173.71it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4200-4250 of 4789 from portal
# Retrieving portal items: 8500it [00:48, 174.37it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4250-4300 of 4789 from portal
# Retrieving portal items: 8600it [00:48, 174.11it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4300-4350 of 4789 from portal
# Retrieving portal items: 8700it [00:49, 174.29it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4350-4400 of 4789 from portal
# Retrieving portal items: 8800it [00:49, 174.61it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4400-4450 of 4789 from portal
# Retrieving portal items: 8900it [00:50, 175.06it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4450-4500 of 4789 from portal
# Retrieving portal items: 9000it [00:51, 174.70it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4500-4550 of 4789 from portal
# Retrieving portal items: 9100it [00:51, 173.22it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4550-4600 of 4789 from portal
# Retrieving portal items: 9200it [00:52, 173.10it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4600-4650 of 4789 from portal
# Retrieving portal items: 9300it [00:52, 173.43it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4650-4700 of 4789 from portal
# Retrieving portal items: 9400it [00:53, 173.55it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4700-4750 of 4789 from portal
# Retrieving portal items: 9500it [00:53, 173.58it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4750-4800 of 4789 from portal
# Retrieving portal items: 9600it [00:54, 173.69it/s]INFO:__main__:Successfully retrieved 100 items from portal
# Retrieving portal items: 9600it [00:54, 175.98it/s]
# INFO:__main__:Completed retrieval for portal. Got 9600 items
# INFO:__main__:Exporting portal analysis to nechako_analysis/portal_library_analysis.xlsx
# INFO:__main__:Writing 31 collections...
# INFO:__main__:Writing 9600 items...
# INFO:__main__:Writing 996 collection items...
# INFO:__main__:Completed export for portal
# INFO:__main__:
# Starting analysis of search library...
# INFO:__main__:Getting collections for search...
# INFO:__main__:Found 4 collections in search
# Processing search collections:   0%|          | 0/4 [00:00<?, ?it/s]INFO:__main__:Retrieved 1 items from collection: Books and Book chapters
# INFO:__main__:Retrieved 100 items from collection: Journal Articles
# INFO:__main__:Retrieved 69 items from collection: Other non-journal sources
# INFO:__main__:Retrieved 43 items from collection: Subsearch AH
# Processing search collections: 100%|██████████| 4/4 [00:00<00:00, 50.34it/s]
# INFO:__main__:Starting retrieval of all items from search...
# Retrieving search items:   0%|          | 0/1316 [00:00<?, ?it/s]INFO:__main__:Fetching items 0-50 of 1316 from search
# INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 50-100 of 1316 from search
# Retrieving search items:  15%|█▌        | 200/1316 [00:00<00:03, 347.82it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 100-150 of 1316 from search
# Retrieving search items:  23%|██▎       | 300/1316 [00:01<00:04, 251.09it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 150-200 of 1316 from search
# Retrieving search items:  30%|███       | 400/1316 [00:01<00:04, 218.92it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 200-250 of 1316 from search
# Retrieving search items:  38%|███▊      | 500/1316 [00:02<00:04, 203.80it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 250-300 of 1316 from search
# Retrieving search items:  46%|████▌     | 600/1316 [00:02<00:03, 196.63it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 300-350 of 1316 from search
# Retrieving search items:  53%|█████▎    | 700/1316 [00:03<00:03, 192.22it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 350-400 of 1316 from search
# Retrieving search items:  61%|██████    | 800/1316 [00:03<00:02, 188.63it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 400-450 of 1316 from search
# Retrieving search items:  68%|██████▊   | 900/1316 [00:04<00:02, 186.11it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 450-500 of 1316 from search
# Retrieving search items:  76%|███████▌  | 1000/1316 [00:04<00:01, 185.83it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 500-550 of 1316 from search
# Retrieving search items:  84%|████████▎ | 1100/1316 [00:05<00:01, 184.39it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 550-600 of 1316 from search
# Retrieving search items:  91%|█████████ | 1200/1316 [00:06<00:00, 184.09it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 600-650 of 1316 from search
# Retrieving search items:  99%|█████████▉| 1300/1316 [00:06<00:00, 183.40it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 650-700 of 1316 from search
# Retrieving search items: 1400it [00:07, 181.77it/s]                          INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 700-750 of 1316 from search
# Retrieving search items: 1500it [00:07, 180.91it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 750-800 of 1316 from search
# Retrieving search items: 1600it [00:08, 180.90it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 800-850 of 1316 from search
# Retrieving search items: 1700it [00:08, 180.29it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 850-900 of 1316 from search
# Retrieving search items: 1800it [00:09, 180.97it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 900-950 of 1316 from search
# Retrieving search items: 1900it [00:09, 180.19it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 950-1000 of 1316 from search
# Retrieving search items: 2000it [00:10, 179.91it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 1000-1050 of 1316 from search
# Retrieving search items: 2100it [00:11, 180.36it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 1050-1100 of 1316 from search
# Retrieving search items: 2200it [00:11, 180.42it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 1100-1150 of 1316 from search
# Retrieving search items: 2300it [00:12, 180.60it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 1150-1200 of 1316 from search
# Retrieving search items: 2400it [00:12, 180.16it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 1200-1250 of 1316 from search
# Retrieving search items: 2500it [00:13, 180.16it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 1250-1300 of 1316 from search
# Retrieving search items: 2600it [00:13, 180.25it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 1300-1350 of 1316 from search
# Retrieving search items: 2700it [00:14, 180.40it/s]INFO:__main__:Successfully retrieved 100 items from search
# Retrieving search items: 2700it [00:14, 187.54it/s]
# INFO:__main__:Completed retrieval for search. Got 2700 items
# INFO:__main__:Exporting search analysis to nechako_analysis/search_library_analysis.xlsx
# INFO:__main__:Writing 4 collections...
# INFO:__main__:Writing 2700 items...
# INFO:__main__:Writing 213 collection items...
# INFO:__main__:Completed export for search
# INFO:__main__:
# Performing duplicate analysis...
# INFO:__main__:Starting duplicate analysis...
# INFO:__main__:Processing portal library for duplicates...
# Retrieving portal items:   0%|          | 0/4789 [00:00<?, ?it/s]INFO:__main__:Fetching items 0-50 of 4789 from portal
# INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 50-100 of 4789 from portal
# Retrieving portal items:   4%|▍         | 200/4789 [00:00<00:14, 317.03it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 100-150 of 4789 from portal
# Retrieving portal items:   6%|▋         | 300/4789 [00:01<00:18, 236.42it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 150-200 of 4789 from portal
# Retrieving portal items:   8%|▊         | 400/4789 [00:01<00:20, 210.04it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 200-250 of 4789 from portal
# Retrieving portal items:  10%|█         | 500/4789 [00:02<00:21, 196.10it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 250-300 of 4789 from portal
# Retrieving portal items:  13%|█▎        | 600/4789 [00:02<00:22, 189.40it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 300-350 of 4789 from portal
# Retrieving portal items:  15%|█▍        | 700/4789 [00:03<00:22, 184.19it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 350-400 of 4789 from portal
# Retrieving portal items:  17%|█▋        | 800/4789 [00:04<00:22, 181.17it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 400-450 of 4789 from portal
# Retrieving portal items:  19%|█▉        | 900/4789 [00:04<00:21, 179.21it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 450-500 of 4789 from portal
# Retrieving portal items:  21%|██        | 1000/4789 [00:05<00:21, 178.25it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 500-550 of 4789 from portal
# Retrieving portal items:  23%|██▎       | 1100/4789 [00:05<00:20, 177.61it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 550-600 of 4789 from portal
# Retrieving portal items:  25%|██▌       | 1200/4789 [00:06<00:20, 176.87it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 600-650 of 4789 from portal
# Retrieving portal items:  27%|██▋       | 1300/4789 [00:06<00:19, 176.42it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items
/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2050-2100 of 4789 from portal
# Retrieving portal items:  88%|████████▊ | 4200/4789 [00:23<00:03, 175.32it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2100-2150 of 4789 from portal
# Retrieving portal items:  90%|████████▉ | 4300/4789 [00:24<00:02, 175.39it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2150-2200 of 4789 from portal
# Retrieving portal items:  92%|█████████▏| 4400/4789 [00:24<00:02, 176.05it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2200-2250 of 4789 from portal
# Retrieving portal items:  94%|█████████▍| 4500/4789 [00:25<00:01, 176.07it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2250-2300 of 4789 from portal
# Retrieving portal items:  96%|█████████▌| 4600/4789 [00:25<00:01, 176.04it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2300-2350 of 4789 from portal
# Retrieving portal items:  98%|█████████▊| 4700/4789 [00:26<00:00, 176.17it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2350-2400 of 4789 from portal
# Retrieving portal items: 4800it [00:26, 176.01it/s]                          INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2400-2450 of 4789 from portal
# Retrieving portal items: 4900it [00:27, 176.28it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2450-2500 of 4789 from portal
# Retrieving portal items: 5000it [00:28, 175.71it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2500-2550 of 4789 from portal
# Retrieving portal items: 5100it [00:28, 175.96it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2550-2600 of 4789 from portal
# Retrieving portal items: 5200it [00:29, 175.46it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2600-2650 of 4789 from portal
# Retrieving portal items: 5300it [00:29, 175.33it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2650-2700 of 4789 from portal
# Retrieving portal items: 5400it [00:30, 166.15it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2700-2750 of 4789 from portal
# Retrieving portal items: 5500it [00:30, 169.70it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2750-2800 of 4789 from portal
# Retrieving portal items: 5600it [00:31, 170.54it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2800-2850 of 4789 from portal
# Retrieving portal items: 5700it [00:32, 171.28it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2850-2900 of 4789 from portal
# Retrieving portal items: 5800it [00:32, 172.07it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2900-2950 of 4789 from portal
# Retrieving portal items: 5900it [00:33, 172.75it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2950-3000 of 4789 from portal
# Retrieving portal items: 6000it [00:33, 173.08it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3000-3050 of 4789 from portal
# Retrieving portal items: 6100it [00:34, 173.52it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3050-3100 of 4789 from portal
# Retrieving portal items: 6200it [00:35, 174.25it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3100-3150 of 4789 from portal
# Retrieving portal items: 6300it [00:35, 173.86it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3150-3200 of 4789 from portal
# Retrieving portal items: 6400it [00:36, 174.26it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3200-3250 of 4789 from portal
# Retrieving portal items: 6500it [00:36, 174.75it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3250-3300 of 4789 from portal
# Retrieving portal items: 6600it [00:37, 175.85it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3300-3350 of 4789 from portal
# Retrieving portal items: 6700it [00:37, 177.67it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3350-3400 of 4789 from portal
# Retrieving portal items: 6800it [00:38, 176.95it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3400-3450 of 4789 from portal
# Retrieving portal items: 6900it [00:38, 176.72it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3450-3500 of 4789 from portal
# Retrieving portal items: 7000it [00:39, 176.02it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3500-3550 of 4789 from portal
# Retrieving portal items: 7100it [00:40, 176.13it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3550-3600 of 4789 from portal
# Retrieving portal items: 7200it [00:40, 175.46it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3600-3650 of 4789 from portal
# Retrieving portal items: 7300it [00:41, 175.81it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3650-3700 of 4789 from portal
# Retrieving portal items: 7400it [00:41, 175.99it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3700-3750 of 4789 from portal
# Retrieving portal items: 7500it [00:42, 175.20it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3750-3800 of 4789 from portal
# Retrieving portal items: 7600it [00:42, 175.32it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3800-3850 of 4789 from portal
# Retrieving portal items: 7700it [00:43, 175.00it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3850-3900 of 4789 from portal
# Retrieving portal items: 7800it [00:44, 174.90it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3900-3950 of 4789 from portal
# Retrieving portal items: 7900it [00:44, 175.38it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3950-4000 of 4789 from portal
# Retrieving portal items: 8000it [00:45, 175.62it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4000-4050 of 4789 from portal
# Retrieving portal items: 8100it [00:45, 175.58it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4050-4100 of 4789 from portal
# Retrieving portal items: 8200it [00:46, 174.99it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4100-4150 of 4789 from portal
# Retrieving portal items: 8300it [00:46, 173.55it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4150-4200 of 4789 from portal
# Retrieving portal items: 8400it [00:47, 173.75it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4200-4250 of 4789 from portal
# Retrieving portal items: 8500it [00:48, 173.65it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4250-4300 of 4789 from portal
# Retrieving portal items: 8600it [00:48, 173.70it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4300-4350 of 4789 from portal
# Retrieving portal items: 8700it [00:49, 174.22it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4350-4400 of 4789 from portal
# Retrieving portal items: 8800it [00:49, 174.30it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4400-4450 of 4789 from portal
# Retrieving portal items: 8900it [00:50, 175.16it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4450-4500 of 4789 from portal
# Retrieving portal items: 9000it [00:51, 174.51it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4500-4550 of 4789 from portal
# Retrieving portal items: 9100it [00:51, 174.35it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4550-4600 of 4789 from portal
# Retrieving portal items: 9200it [00:52, 174.11it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4600-4650 of 4789 from portal
# Retrieving portal items: 9300it [00:52, 174.56it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4650-4700 of 4789 from portal
# Retrieving portal items: 9400it [00:53, 174.50it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4700-4750 of 4789 from portal
# Retrieving portal items: 9500it [00:53, 174.59it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4750-4800 of 4789 from portal
# Retrieving portal items: 9600it [00:54, 174.43it/s]INFO:__main__:Successfully retrieved 100 items from portal
# Retrieving portal items: 9600it [00:54, 176.33it/s]
# INFO:__main__:Completed retrieval for portal. Got 9600 items
# Processing portal titles: 100%|██████████| 9600/9600 [00:00<00:00, 1386642.28it/s]
# INFO:__main__:Processing search library for duplicates...
# Retrieving search items:   0%|          | 0/1316 [00:00<?, ?it/s]INFO:__main__:Fetching items 0-50 of 1316 from search
# INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 50-100 of 1316 from search
# Retrieving search items:  15%|█▌        | 200/1316 [00:00<00:03, 344.51it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 100-150 of 1316 from search
# Retrieving search items:  23%|██▎       | 300/1316 [00:01<00:04, 249.92it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 150-200 of 1316 from search
# Retrieving search items:  30%|███       | 400/1316 [00:01<00:04, 218.05it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 200-250 of 1316 from search
# Retrieving search items:  38%|███▊      | 500/1316 [00:02<00:03, 204.16it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 250-300 of 1316 from search
# Retrieving search items:  46%|████▌     | 600/1316 [00:02<00:03, 195.25it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 300-350 of 1316 from search
# Retrieving search items:  53%|█████▎    | 700/1316 [00:03<00:03, 190.51it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 350-400 of 1316 from search
# Retrieving search items:  61%|██████    | 800/1316 [00:03<00:02, 187.16it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 400-450 of 1316 from search
# Retrieving search items:  68%|██████▊   | 900/1316 [00:04<00:02, 185.33it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 450-500 of 1316 from search
# Retrieving search items:  76%|███████▌  | 1000/1316 [00:05<00:01, 183.96it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 500-550 of 1316 from search
# Retrieving search items:  84%|████████▎ | 1100/1316 [00:05<00:01, 182.59it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 550-600 of 1316 from search
# Retrieving search items:  91%|█████████ | 1200/1316 [00:06<00:00, 181.67it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 600-650 of 1316 from search
# Retrieving search items:  99%|█████████▉| 1300/1316 [00:06<00:00, 180.87it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 650-700 of 1316 from search
# Retrieving search items: 1400it [00:07, 181.12it/s]                          INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 700-750 of 1316 from search
# Retrieving search items: 1500it [00:07, 180.81it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 750-800 of 1316 from search
# Retrieving search items: 1600it [00:08, 180.86it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 800-850 of 1316 from search
# Retrieving search items: 1700it [00:08, 180.76it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 850-900 of 1316 from search
# Retrieving search items: 1800it [00:09, 180.77it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 900-950 of 1316 from search
# Retrieving search items: 1900it [00:09, 180.88it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 950-1000 of 1316 from search
# Retrieving search items: 2000it [00:10, 180.59it/s]INFO:__main__:Successfully retrieved 100 items from search
# ...
# INFO:__main__:Fetching items 1850-1900 of 4789 from portal
# Retrieving portal items:  79%|███████▉  | 3800/4789 [00:20<00:05, 178.71it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 1900-1950 of 4789 from portal
# Retrieving portal items:  81%|████████▏ | 3900/4789 [00:21<00:04, 178.41it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 1950-2000 of 4789 from portal
# Retrieving portal items:  84%|████████▎ | 4000/4789 [00:22<00:04, 178.23it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2000-2050 of 4789 from portal
# Retrieving portal items:  86%|████████▌ | 4100/4789 [00:22<00:03, 177.69it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2050-2100 of 4789 from portal
# Retrieving portal items:  88%|████████▊ | 4200/4789 [00:23<00:03, 178.10it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2100-2150 of 4789 from portal
# Retrieving portal items:  90%|████████▉ | 4300/4789 [00:23<00:02, 178.48it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2150-2200 of 4789 from portal
# Retrieving portal items:  92%|█████████▏| 4400/4789 [00:24<00:02, 178.81it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2200-2250 of 4789 from portal
# Retrieving portal items:  94%|█████████▍| 4500/4789 [00:24<00:01, 177.42it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2250-2300 of 4789 from portal
# Retrieving portal items:  96%|█████████▌| 4600/4789 [00:25<00:01, 178.11it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2300-2350 of 4789 from portal
# Retrieving portal items:  98%|█████████▊| 4700/4789 [00:25<00:00, 177.00it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2350-2400 of 4789 from portal
# Retrieving portal items: 4800it [00:26, 175.36it/s]                          INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2400-2450 of 4789 from portal
# Retrieving portal items: 4900it [00:27, 175.81it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2450-2500 of 4789 from portal
# Retrieving portal items: 5000it [00:27, 175.60it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2500-2550 of 4789 from portal
# Retrieving portal items: 5100it [00:28, 175.17it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2550-2600 of 4789 from portal
# Retrieving portal items: 5200it [00:28, 175.13it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2600-2650 of 4789 from portal
# Retrieving portal items: 5300it [00:29, 175.92it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2650-2700 of 4789 from portal
# Retrieving portal items: 5400it [00:29, 175.73it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2700-2750 of 4789 from portal
# Retrieving portal items: 5500it [00:30, 175.57it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2750-2800 of 4789 from portal
# Retrieving portal items: 5600it [00:31, 175.23it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2800-2850 of 4789 from portal
# Retrieving portal items: 5700it [00:31, 175.27it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2850-2900 of 4789 from portal
# Retrieving portal items: 5800it [00:32, 174.92it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2900-2950 of 4789 from portal
# Retrieving portal items: 5900it [00:32, 174.66it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 2950-3000 of 4789 from portal
# Retrieving portal items: 6000it [00:33, 174.46it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3000-3050 of 4789 from portal
# Retrieving portal items: 6100it [00:34, 174.21it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3050-3100 of 4789 from portal
# Retrieving portal items: 6200it [00:34, 174.21it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3100-3150 of 4789 from portal
# Retrieving portal items: 6300it [00:35, 174.50it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3150-3200 of 4789 from portal
# Retrieving portal items: 6400it [00:35, 174.28it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3200-3250 of 4789 from portal
# Retrieving portal items: 6500it [00:36, 174.65it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3250-3300 of 4789 from portal
# Retrieving portal items: 6600it [00:36, 174.64it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3300-3350 of 4789 from portal
# Retrieving portal items: 6700it [00:37, 175.19it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3350-3400 of 4789 from portal
# Retrieving portal items: 6800it [00:38, 173.79it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3400-3450 of 4789 from portal
# Retrieving portal items: 6900it [00:38, 173.56it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3450-3500 of 4789 from portal
# Retrieving portal items: 7000it [00:39, 172.35it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3500-3550 of 4789 from portal
# Retrieving portal items: 7100it [00:39, 173.11it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3550-3600 of 4789 from portal
# Retrieving portal items: 7200it [00:40, 173.59it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3600-3650 of 4789 from portal
# Retrieving portal items: 7300it [00:40, 173.92it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3650-3700 of 4789 from portal
# Retrieving portal items: 7400it [00:41, 174.22it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3700-3750 of 4789 from portal
# Retrieving portal items: 7500it [00:42, 174.15it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3750-3800 of 4789 from portal
# Retrieving portal items: 7600it [00:42, 174.50it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3800-3850 of 4789 from portal
# Retrieving portal items: 7700it [00:43, 174.36it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3850-3900 of 4789 from portal
# Retrieving portal items: 7800it [00:43, 174.78it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3900-3950 of 4789 from portal
# Retrieving portal items: 7900it [00:44, 174.82it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 3950-4000 of 4789 from portal
# Retrieving portal items: 8000it [00:44, 174.70it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4000-4050 of 4789 from portal
# Retrieving portal items: 8100it [00:45, 174.77it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4050-4100 of 4789 from portal
# Retrieving portal items: 8200it [00:46, 175.13it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4100-4150 of 4789 from portal
# Retrieving portal items: 8300it [00:46, 176.06it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4150-4200 of 4789 from portal
# Retrieving portal items: 8400it [00:47, 174.53it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4200-4250 of 4789 from portal
# Retrieving portal items: 8500it [00:47, 174.98it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4250-4300 of 4789 from portal
# Retrieving portal items: 8600it [00:48, 175.28it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4300-4350 of 4789 from portal
# Retrieving portal items: 8700it [00:48, 175.24it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4350-4400 of 4789 from portal
# Retrieving portal items: 8800it [00:49, 174.88it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4400-4450 of 4789 from portal
# Retrieving portal items: 8900it [00:50, 174.54it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4450-4500 of 4789 from portal
# Retrieving portal items: 9000it [00:50, 174.67it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4500-4550 of 4789 from portal
# Retrieving portal items: 9100it [00:51, 175.58it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4550-4600 of 4789 from portal
# Retrieving portal items: 9200it [00:51, 175.15it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4600-4650 of 4789 from portal
# Retrieving portal items: 9300it [00:52, 165.11it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4650-4700 of 4789 from portal
# Retrieving portal items: 9400it [00:53, 168.13it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4700-4750 of 4789 from portal
# Retrieving portal items: 9500it [00:53, 170.26it/s]INFO:__main__:Successfully retrieved 100 items from portal
# INFO:__main__:Fetching items 4750-4800 of 4789 from portal
# Retrieving portal items: 9600it [00:54, 171.47it/s]INFO:__main__:Successfully retrieved 100 items from portal
# Retrieving portal items: 9600it [00:54, 177.25it/s]
# INFO:__main__:Completed retrieval for portal. Got 9600 items
# Processing portal titles: 100%|██████████| 9600/9600 [00:00<00:00, 1195064.80it/s]
# INFO:__main__:Processing search library for duplicates...
# Retrieving search items:   0%|          | 0/1316 [00:00<?, ?it/s]INFO:__main__:Fetching items 0-50 of 1316 from search
# INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 50-100 of 1316 from search
# Retrieving search items:  15%|█▌        | 200/1316 [00:00<00:03, 345.16it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 100-150 of 1316 from search
# Retrieving search items:  23%|██▎       | 300/1316 [00:01<00:04, 252.23it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 150-200 of 1316 from search
# Retrieving search items:  30%|███       | 400/1316 [00:01<00:04, 219.53it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 200-250 of 1316 from search
# Retrieving search items:  38%|███▊      | 500/1316 [00:02<00:03, 204.71it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 250-300 of 1316 from search
# Retrieving search items:  46%|████▌     | 600/1316 [00:02<00:03, 195.86it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 300-350 of 1316 from search
# Retrieving search items:  53%|█████▎    | 700/1316 [00:03<00:03, 190.27it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 350-400 of 1316 from search
# Retrieving search items:  61%|██████    | 800/1316 [00:03<00:02, 187.86it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 400-450 of 1316 from search
# Retrieving search items:  68%|██████▊   | 900/1316 [00:04<00:02, 185.70it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 450-500 of 1316 from search
# Retrieving search items:  76%|███████▌  | 1000/1316 [00:04<00:01, 183.98it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 500-550 of 1316 from search
# Retrieving search items:  84%|████████▎ | 1100/1316 [00:05<00:01, 183.08it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 550-600 of 1316 from search
# Retrieving search items:  91%|█████████ | 1200/1316 [00:06<00:00, 182.78it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 600-650 of 1316 from search
# Retrieving search items:  99%|█████████▉| 1300/1316 [00:06<00:00, 182.06it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 650-700 of 1316 from search
# Retrieving search items: 1400it [00:07, 181.28it/s]                          INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 700-750 of 1316 from search
# Retrieving search items: 1500it [00:07, 181.58it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 750-800 of 1316 from search
# Retrieving search items: 1600it [00:08, 181.22it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 800-850 of 1316 from search
# Retrieving search items: 1700it [00:08, 180.77it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 850-900 of 1316 from search
# Retrieving search items: 1800it [00:09, 180.62it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 900-950 of 1316 from search
# Retrieving search items: 1900it [00:09, 180.68it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 950-1000 of 1316 from search
# Retrieving search items: 2000it [00:10, 180.33it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 1000-1050 of 1316 from search
# Retrieving search items: 2100it [00:11, 179.59it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 1050-1100 of 1316 from search
# Retrieving search items: 2200it [00:11, 180.15it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 1100-1150 of 1316 from search
# Retrieving search items: 2300it [00:12, 180.84it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 1150-1200 of 1316 from search
# Retrieving search items: 2400it [00:12, 180.58it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 1200-1250 of 1316 from search
# Retrieving search items: 2500it [00:13, 180.70it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 1250-1300 of 1316 from search
# Retrieving search items: 2600it [00:13, 180.72it/s]INFO:__main__:Successfully retrieved 100 items from search
# INFO:__main__:Fetching items 1300-1350 of 1316 from search
# Retrieving search items: 2700it [00:14, 180.70it/s]INFO:__main__:Successfully retrieved 100 items from search
# Retrieving search items: 2700it [00:14, 187.35it/s]
# INFO:__main__:Completed retrieval for search. Got 2700 items
# Processing search titles: 100%|██████████| 2700/2700 [00:00<00:00, 135904.15it/s]
# INFO:__main__:Found 1 duplicate titles
# INFO:__main__:Creating Venn diagram...
# Processing duplicates: 100%|██████████| 1/1 [00:00<00:00, 41527.76it/s]
# Analysis Summary:
# Portal Library Items: 100
# Search Library Items: 70
# Duplicate Items: 1
#
# Analysis completed at: 2024-12-03 12:24:44
# Total duration: 0:03:31.633023

# %%
from pyzotero import zotero
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
import os
import logging
from time import sleep
from datetime import datetime
from tqdm import tqdm
import xml.etree.ElementTree as ET

class ZoteroGroupAnalyzer:
    def __init__(self, xml_paths=None):
        """Initialize the analyzer with specific Nechako group libraries using the local Zotero API."""
        self.libraries = {
            'portal': zotero.Zotero('364018', 'group', local=True),
            'search': zotero.Zotero('5494504', 'group', local=True)
        }
        
        self.xml_paths = xml_paths or {}
        self.xml_data = {}
        
        # Set up logging with timestamps
        logging.basicConfig(
            level=logging.INFO,
            format='%(asctime)s - %(message)s',
            datefmt='%Y-%m-%d %H:%M:%S'
        )
        self.logger = logging.getLogger(__name__)
        
        # Verify connections and get total counts
        self.total_counts = {}
        for name, zot in self.libraries.items():
            try:
                items = zot.items(limit=1)
                total = zot.count_items()
                self.total_counts[name] = total
                self.logger.info(f"Connected to {name} library. Total items: {total}")
            except Exception as e:
                self.logger.error(f"Failed to connect to {name} library: {str(e)}")
                raise

        if self.xml_paths:
            self._load_xml_data()

    def get_all_items(self, zot, library_name):
        """Safely retrieve all items with detailed progress tracking."""
        all_items = []
        start = 0
        limit = 50
        total = self.total_counts[library_name]
        
        # Create progress bar
        with tqdm(total=total, desc=f"Retrieving {library_name} items") as pbar:
            while True:
                try:
                    self.logger.info(f"Fetching items {start}-{start+limit} of {total} from {library_name}")
                    items = zot.items(start=start, limit=limit)
                    if not items:
                        break
                    
                    all_items.extend(items)
                    items_added = len(items)
                    pbar.update(items_added)
                    
                    self.logger.info(f"Successfully retrieved {items_added} items from {library_name}")
                    start += limit
                    
                    if start >= total:
                        break
                    
                    sleep(0.5)  # Prevent overloading
                    
                except Exception as e:
                    self.logger.warning(f"Error retrieving items at offset {start}: {str(e)}")
                    if start > 0:  # If we've already gotten some items, return those
                        break
                    else:
                        raise
        
        self.logger.info(f"Completed retrieval for {library_name}. Got {len(all_items)} items")
        return all_items

    def _load_xml_data(self):
        """Load and parse XML files."""
        for library_name, paths in self.xml_paths.items():
            self.xml_data[library_name] = {
                'deduplicated': self._parse_xml(paths['deduplicated']),
                'duplicates': self._parse_xml(paths['duplicates'])
            }
            self.logger.info(f"Loaded XML data for {library_name}")

    def _parse_xml(self, file_path):
        """Parse XML file and return structured data."""
        try:
            tree = ET.parse(file_path)
            root = tree.getroot()
            
            items = []
            for entry in root.findall('.//entry'):
                item = {
                    'title': entry.find('title').text if entry.find('title') is not None else '',
                    'authors': [author.text for author in entry.findall('.//author')],
                    'doi': entry.find('doi').text if entry.find('doi') is not None else '',
                    'year': entry.find('year').text if entry.find('year') is not None else '',
                }
                items.append(item)
            
            return items
            
        except Exception as e:
            self.logger.error(f"Error parsing XML file {file_path}: {str(e)}")
            return []

    def extract_library_structure(self, library_name):
        """Extract complete structure with progress tracking."""
        zot = self.libraries[library_name]
        structure = {
            'collections': [],
            'items': [],
            'collection_items': []
        }
        
        try:
            # Get collections with progress tracking
            self.logger.info(f"Getting collections for {library_name}...")
            collections = zot.collections()
            self.logger.info(f"Found {len(collections)} collections in {library_name}")
            
            # Process collections with progress bar
            with tqdm(collections, desc=f"Processing {library_name} collections") as pbar:
                for coll in pbar:
                    structure['collections'].append({
                        'key': coll['key'],
                        'name': coll['data']['name'],
                        'parent': coll['data'].get('parentCollection', None)
                    })
                    
                    try:
                        items = zot.collection_items(coll['key'])
                        self.logger.info(f"Retrieved {len(items)} items from collection: {coll['data']['name']}")
                        for item in items:
                            structure['collection_items'].append({
                                'collection_key': coll['key'],
                                'item_key': item['key'],
                                'collection_name': coll['data']['name'],
                                'title': item['data'].get('title', ''),
                                'item_type': item['data'].get('itemType', '')
                            })
                    except Exception as e:
                        self.logger.warning(f"Error getting items for collection {coll['data']['name']}: {str(e)}")
            
            # Get all items using progress tracking
            self.logger.info(f"Starting retrieval of all items from {library_name}...")
            all_items = self.get_all_items(zot, library_name)
            structure['items'] = all_items
            
            return structure
            
        except Exception as e:
            self.logger.error(f"Error extracting structure from {library_name}: {str(e)}")
            raise

    def analyze_duplicates(self):
        """Compare libraries with progress tracking."""
        try:
            self.logger.info("Starting duplicate analysis...")
            
            # Get items from both libraries
            portal_items = {}
            search_items = {}
            
            for lib_name, items_dict in [('portal', portal_items), ('search', search_items)]:
                self.logger.info(f"Processing {lib_name} library for duplicates...")
                all_items = self.get_all_items(self.libraries[lib_name], lib_name)
                
                # Process items with progress bar
                with tqdm(all_items, desc=f"Processing {lib_name} titles") as pbar:
                    for item in pbar:
                        if 'title' in item['data']:
                            items_dict[item['data']['title'].lower()] = item
            
            # Find duplicates
            duplicate_titles = set(portal_items.keys()) & set(search_items.keys())
            self.logger.info(f"Found {len(duplicate_titles)} duplicate titles")
            
            # Create visualization
            self.logger.info("Creating Venn diagram...")
            plt.figure(figsize=(10, 10))
            venn2([set(portal_items.keys()), set(search_items.keys())],
                  set_labels=('Portal Library', 'Search Library'))
            plt.title('Library Content Overlap')
            plt.savefig('library_overlap.png')
            plt.close()
            
            # Process duplicates with progress bar
            duplicates_data = []
            with tqdm(duplicate_titles, desc="Processing duplicates") as pbar:
                for title in pbar:
                    duplicates_data.append({
                        'title': title,
                        'portal_id': portal_items[title]['key'] if title in portal_items else '',
                        'search_id': search_items[title]['key'] if title in search_items else '',
                        'item_type': portal_items[title]['data'].get('itemType', '') if title in portal_items else search_items[title]['data'].get('itemType', '')
                    })
            
            duplicates_df = pd.DataFrame(duplicates_data)
            
            return {
                'duplicates': duplicate_titles,
                'duplicates_df': duplicates_df,
                'stats': {
                    'portal_total': len(portal_items),
                    'search_total': len(search_items),
                    'duplicate_count': len(duplicate_titles)
                }
            }
            
        except Exception as e:
            self.logger.error(f"Error analyzing duplicates: {str(e)}")
            raise

    def export_analysis(self, output_dir='nechako_analysis'):
        """Export analysis with progress tracking."""
        try:
            os.makedirs(output_dir, exist_ok=True)
            self.logger.info(f"Created output directory: {output_dir}")
            
            # Process each library
            for lib_name in self.libraries:
                self.logger.info(f"\nStarting analysis of {lib_name} library...")
                structure = self.extract_library_structure(lib_name)
                
                # Export to Excel with progress updates
                excel_path = os.path.join(output_dir, f'{lib_name}_library_analysis.xlsx')
                self.logger.info(f"Exporting {lib_name} analysis to {excel_path}")
                
                with pd.ExcelWriter(excel_path) as writer:
                    # Collections
                    self.logger.info(f"Writing {len(structure['collections'])} collections...")
                    pd.DataFrame(structure['collections']).to_excel(writer, sheet_name='Collections', index=False)
                    
                    # Items
                    self.logger.info(f"Writing {len(structure['items'])} items...")
                    try:
                        items_df = pd.json_normalize([item['data'] for item in structure['items']])
                    except Exception as e:
                        self.logger.warning(f"Error normalizing items data: {str(e)}")
                        items_df = pd.DataFrame(structure['items'])
                    items_df.to_excel(writer, sheet_name='Items', index=False)
                    
                    # Collection items
                    self.logger.info(f"Writing {len(structure['collection_items'])} collection items...")
                    pd.DataFrame(structure['collection_items']).to_excel(writer, sheet_name='Collection_Items', index=False)
                
                self.logger.info(f"Completed export for {lib_name}")
            
            # Export duplicate analysis
            self.logger.info("\nPerforming duplicate analysis...")
            duplicate_analysis = self.analyze_duplicates()
            
            if self.xml_paths:
                xml_analysis = self.analyze_with_xml()
                self.export_xml_analysis(xml_analysis, output_dir)
                
            duplicate_path = os.path.join(output_dir, 'duplicate_analysis.xlsx')
            
            self.logger.info("Exporting duplicate analysis...")
            with pd.ExcelWriter(duplicate_path) as writer:
                pd.DataFrame([duplicate_analysis['stats']]).to_excel(writer, sheet_name='Summary', index=False)
                if 'duplicates_df' in duplicate_analysis:
                    duplicate_analysis['duplicates_df'].to_excel(writer, sheet_name='Detailed_Duplicates', index=False)
            
            self.logger.info(f"Analysis export completed. Files saved in: {output_dir}")
            
        except Exception as e:
            self.logger.error(f"Error exporting analysis: {str(e)}")
            raise

    def analyze_with_xml(self):
        """Analyze libraries with XML integration."""
        try:
            self.logger.info("Starting integrated analysis...")
            results = {}
            
            for lib_name in self.libraries:
                if lib_name not in self.xml_data:
                    continue
                    
                self.logger.info(f"Processing {lib_name} library...")
                zotero_items = self.get_all_items(self.libraries[lib_name], lib_name)
                xml_items = self.xml_data[lib_name]
                
                # Match items
                matches = self._match_items(zotero_items, xml_items)
                
                results[lib_name] = {
                    'total_zotero': len(zotero_items),
                    'total_deduplicated': len(xml_items.get('deduplicated', [])),
                    'total_duplicates': len(xml_items.get('duplicates', [])),
                    'matches': matches
                }
            
            return results
            
        except Exception as e:
            self.logger.error(f"Error in XML analysis: {str(e)}")
            raise

    def _match_items(self, zotero_items, xml_items):
        """Match Zotero items with XML items."""
        matches = []
        
        for zot_item in tqdm(zotero_items, desc="Matching items"):
            zot_title = zot_item['data'].get('title', '').lower()
            if not zot_title:
                continue
                
            # Check in deduplicated items
            for xml_item in xml_items.get('deduplicated', []):
                if xml_item['title'].lower() == zot_title:
                    matches.append({
                        'zotero_item': zot_item,
                        'xml_item': xml_item,
                        'status': 'deduplicated'
                    })
                    break
                    
            # Check in duplicate items
            for xml_item in xml_items.get('duplicates', []):
                if xml_item['title'].lower() == zot_title:
                    matches.append({
                        'zotero_item': zot_item,
                        'xml_item': xml_item,
                        'status': 'duplicate'
                    })
                    break
        
        return matches

    def export_xml_analysis(self, results, output_dir):
        """Export XML analysis results."""
        for lib_name, lib_results in results.items():
            excel_path = os.path.join(output_dir, f'{lib_name}_xml_analysis.xlsx')
            
            with pd.ExcelWriter(excel_path) as writer:
                # Summary
                summary_data = {
                    'Metric': ['Total Zotero Items', 'Total Deduplicated XML Items', 'Total Duplicate XML Items', 'Matched Items'],
                    'Count': [
                        lib_results['total_zotero'],
                        lib_results['total_deduplicated'],
                        lib_results['total_duplicates'],
                        len(lib_results['matches'])
                    ]
                }
                pd.DataFrame(summary_data).to_excel(writer, sheet_name='Summary', index=False)
                
                # Detailed matches
                matches_data = []
                for match in lib_results['matches']:
                    matches_data.append({
                        'Zotero Title': match['zotero_item']['data'].get('title', ''),
                        'XML Title': match['xml_item']['title'],
                        'Status': match['status'],
                        'DOI': match['zotero_item']['data'].get('DOI', ''),
                        'XML DOI': match['xml_item']['doi'],
                        'Year': match['zotero_item']['data'].get('date', '')[:4],
                        'XML Year': match['xml_item']['year'],
                        'Item Type': match['zotero_item']['data'].get('itemType', ''),
                        'Collection Key': match['zotero_item']['key']
                    })
                
                matches_df = pd.DataFrame(matches_data)
                matches_df.to_excel(writer, sheet_name='Matched_Items', index=False)

def main():
    start_time = datetime.now()
    print(f"Analysis started at: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")
    
    try:
        # Define XML file paths
        xml_paths = {
            'search': {
                'deduplicated': '/Users/ahmadjalil/Desktop/Zotero Project/Nechako Saturation Search/Deduplicator/Untitled_deduplicated 2024-12-02_Time0911.xml',
                'duplicates': '/Users/ahmadjalil/Desktop/Zotero Project/Nechako Saturation Search/Deduplicator/Untitled_removed_duplicates 2024-12-02_Time0911.xml'
            }
            # Add portal paths when available
        }
        
        # Initialize analyzer with XML paths
        analyzer = ZoteroGroupAnalyzer(xml_paths)
        
        # Export both standard and XML analysis
        analyzer.export_analysis()
        
        # Print summary
        duplicate_analysis = analyzer.analyze_duplicates()
        print("\nAnalysis Summary:")
        print(f"Portal Library Items: {duplicate_analysis['stats']['portal_total']}")
        print(f"Search Library Items: {duplicate_analysis['stats']['search_total']}")
        print(f"Duplicate Items: {duplicate_analysis['stats']['duplicate_count']}")
        
        if analyzer.xml_paths:
            xml_analysis = analyzer.analyze_with_xml()
            print("\nXML Analysis Summary:")
            for lib_name, results in xml_analysis.items():
                print(f"\n{lib_name.title()} Library:")
                print(f"Total Zotero Items: {results['total_zotero']}")
                print(f"Total Deduplicated XML Items: {results['total_deduplicated']}")
                print(f"Total Duplicate XML Items: {results['total_duplicates']}")
                print(f"Matched Items: {len(results['matches'])}")
        
        end_time = datetime.now()
        duration = end_time - start_time
        print(f"\nAnalysis completed at: {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
        print(f"Total duration: {duration}")
        
    except Exception as e:
        print(f"Error during analysis: {str(e)}")
        raise

if __name__ == "__main__":
    main()
# Out:
# 2024-12-04 11:14:21 - Connected to portal library. Total items: 4789
# 2024-12-04 11:14:21 - Connected to search library. Total items: 1316
# 2024-12-04 11:14:21 - Loaded XML data for search
# 2024-12-04 11:14:21 - Created output directory: nechako_analysis
# 2024-12-04 11:14:21 -
# Starting analysis of portal library...
# 2024-12-04 11:14:21 - Getting collections for portal...
# 2024-12-04 11:14:21 - Found 31 collections in portal
# Analysis started at: 2024-12-04 11:14:21
# Processing portal collections:   0%|          | 0/31 [00:00<?, ?it/s]2024-12-04 11:14:21 - Retrieved 0 items from collection: 1. Data Sources
# 2024-12-04 11:14:21 - Retrieved 0 items from collection: Barry's Collection
# 2024-12-04 11:14:21 - Retrieved 0 items from collection: Cheslatta
# 2024-12-04 11:14:21 - Retrieved 0 items from collection: EDI
# 2024-12-04 11:14:21 - Retrieved 100 items from collection: Large Lakes Monitoring
# 2024-12-04 11:14:21 - Retrieved 0 items from collection: NWR
# 2024-12-04 11:14:21 - Retrieved 0 items from collection: Saturation Search
# 2024-12-04 11:14:21 - Retrieved 0 items from collection: 2. Team Work Folder
# 2024-12-04 11:14:21 - Retrieved 0 items from collection: Christiana
# 2024-12-04 11:14:21 - Retrieved 13 items from collection: Isla
# 2024-12-04 11:14:21 - Retrieved 0 items from collection: Jonathan
# Processing portal collections:  35%|███▌      | 11/31 [00:00<00:00, 108.28it/s]2024-12-04 11:14:21 - Retrieved 79 items from collection: Sample 1 (Jan 10th, 2022)
# 2024-12-04 11:14:21 - Retrieved 0 items from collection: Lisa
# 2024-12-04 11:14:21 - Retrieved 9 items from collection: Margot
# 2024-12-04 11:14:21 - Retrieved 100 items from collection: MP-JD Saturation Search (Journals only)
# 2024-12-04 11:14:21 - Retrieved 1 items from collection: Scott
# 2024-12-04 11:14:21 - Retrieved 2 items from collection: 3. Resources for Import
# 2024-12-04 11:14:21 - Retrieved 3 items from collection: Climate Hope/Restoration resources for Import (Makayla)
# 2024-12-04 11:14:21 - Retrieved 78 items from collection: Resources for Import (Christiana)
# 2024-12-04 11:14:21 - Retrieved 76 items from collection: Resources for Import (Jonathan)
# 2024-12-04 11:14:21 - Retrieved 8 items from collection: Resources for Import (Lisa)
# 2024-12-04 11:14:21 - Retrieved 100 items from collection: 4. Uploaded Resources (in the Nechako Portal)
# Processing portal collections:  71%|███████   | 22/31 [00:00<00:00, 86.01it/s] 2024-12-04 11:14:21 - Retrieved 56 items from collection: Subsurface papers
# 2024-12-04 11:14:21 - Retrieved 78 items from collection: Books
# 2024-12-04 11:14:21 - Retrieved 40 items from collection: IWRG paper
# 2024-12-04 11:14:21 - Retrieved 1 items from collection: Movies
# 2024-12-04 11:14:21 - Retrieved 100 items from collection: Nechako Archives
# 2024-12-04 11:14:21 - Retrieved 100 items from collection: Nechako Lit Review Master List
# 2024-12-04 11:14:21 - Retrieved 45 items from collection: Portal Resources
# 2024-12-04 11:14:21 - Retrieved 5 items from collection: Reports
# 2024-12-04 11:14:21 - Retrieved 2 items from collection: Websites
# Processing portal collections: 100%|██████████| 31/31 [00:00<00:00, 83.20it/s]
# 2024-12-04 11:14:21 - Starting retrieval of all items from portal...
# Retrieving portal items:   0%|          | 0/4789 [00:00<?, ?it/s]2024-12-04 11:14:21 - Fetching items 0-50 of 4789 from portal
# 2024-12-04 11:14:21 - Successfully retrieved 100 items from portal
# 2024-12-04 11:14
- Successfully retrieved 100 items from search
# 2024-12-04 11:15:18 - Fetching items 50-100 of 1316 from search
# Retrieving search items:  15%|█▌        | 200/1316 [00:00<00:03, 348.08it/s]2024-12-04 11:15:18 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:19 - Fetching items 100-150 of 1316 from search
# Retrieving search items:  23%|██▎       | 300/1316 [00:01<00:04, 252.63it/s]2024-12-04 11:15:19 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:19 - Fetching items 150-200 of 1316 from search
# Retrieving search items:  30%|███       | 400/1316 [00:01<00:04, 221.52it/s]2024-12-04 11:15:19 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:20 - Fetching items 200-250 of 1316 from search
# Retrieving search items:  38%|███▊      | 500/1316 [00:02<00:03, 205.43it/s]2024-12-04 11:15:20 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:20 - Fetching items 250-300 of 1316 from search
# Retrieving search items:  46%|████▌     | 600/1316 [00:02<00:03, 196.97it/s]2024-12-04 11:15:20 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:21 - Fetching items 300-350 of 1316 from search
# Retrieving search items:  53%|█████▎    | 700/1316 [00:03<00:03, 191.43it/s]2024-12-04 11:15:21 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:21 - Fetching items 350-400 of 1316 from search
# Retrieving search items:  61%|██████    | 800/1316 [00:03<00:02, 188.64it/s]2024-12-04 11:15:22 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:22 - Fetching items 400-450 of 1316 from search
# Retrieving search items:  68%|██████▊   | 900/1316 [00:04<00:02, 187.12it/s]2024-12-04 11:15:22 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:23 - Fetching items 450-500 of 1316 from search
# Retrieving search items:  76%|███████▌  | 1000/1316 [00:04<00:01, 185.40it/s]2024-12-04 11:15:23 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:23 - Fetching items 500-550 of 1316 from search
# Retrieving search items:  84%|████████▎ | 1100/1316 [00:05<00:01, 184.33it/s]2024-12-04 11:15:23 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:24 - Fetching items 550-600 of 1316 from search
# Retrieving search items:  91%|█████████ | 1200/1316 [00:06<00:00, 184.59it/s]2024-12-04 11:15:24 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:24 - Fetching items 600-650 of 1316 from search
# Retrieving search items:  99%|█████████▉| 1300/1316 [00:06<00:00, 183.61it/s]2024-12-04 11:15:24 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:25 - Fetching items 650-700 of 1316 from search
# Retrieving search items: 1400it [00:07, 182.84it/s]                          2024-12-04 11:15:25 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:25 - Fetching items 700-750 of 1316 from search
# Retrieving search items: 1500it [00:07, 182.58it/s]2024-12-04 11:15:25 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:26 - Fetching items 750-800 of 1316 from search
# Retrieving search items: 1600it [00:08, 183.09it/s]2024-12-04 11:15:26 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:26 - Fetching items 800-850 of 1316 from search
# Retrieving search items: 1700it [00:08, 182.78it/s]2024-12-04 11:15:26 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:27 - Fetching items 850-900 of 1316 from search
# Retrieving search items: 1800it [00:09, 182.53it/s]2024-12-04 11:15:27 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:27 - Fetching items 900-950 of 1316 from search
# Retrieving search items: 1900it [00:09, 182.44it/s]2024-12-04 11:15:28 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:28 - Fetching items 950-1000 of 1316 from search
# Retrieving search items: 2000it [00:10, 182.72it/s]2024-12-04 11:15:28 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:29 - Fetching items 1000-1050 of 1316 from search
# Retrieving search items: 2100it [00:10, 182.94it/s]2024-12-04 11:15:29 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:29 - Fetching items 1050-1100 of 1316 from search
# Retrieving search items: 2200it [00:11, 182.62it/s]2024-12-04 11:15:29 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:30 - Fetching items 1100-1150 of 1316 from search
# Retrieving search items: 2300it [00:12, 182.99it/s]2024-12-04 11:15:30 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:30 - Fetching items 1150-1200 of 1316 from search
# Retrieving search items: 2400it [00:12, 183.08it/s]2024-12-04 11:15:30 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:31 - Fetching items 1200-1250 of 1316 from search
# Retrieving search items: 2500it [00:13, 183.20it/s]2024-12-04 11:15:31 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:31 - Fetching items 1250-1300 of 1316 from search
# Retrieving search items: 2600it [00:13, 182.83it/s]2024-12-04 11:15:31 - Successfully retrieved 100 items from search
# 2024-12-04 11:15:32 - Fetching items 1300-1350 of 1316 from search
# Retrieving search items: 2700it [00:14, 182.75it/s]2024-12-04 11:15:32 - Successfully retrieved 100 items from search
# Retrieving search items: 2700it [00:14, 189.20it/s]
# 2024-12-04 11:15:32 - Completed retrieval for search. Got 2700 items
# 2024-12-04 11:15:32 - Exporting search analysis to nechako_analysis/search_library_analysis.xlsx
# 2024-12-04 11:15:32 - Writing 4 collections...
# 2024-12-04 11:15:32 - Writing 2700 items...
# 2024-12-04 11:15:32 - Writing 213 collection items...
# 2024-12-04 11:15:33 - Completed export for search
# 2024-12-04 11:15:33 -
# Performing duplicate analysis...
# 2024-12-04 11:15:33 - Starting duplicate analysis...
# 2024-12-04 11:15:33 - Processing portal library for duplicates...
# Retrieving portal items:   0%|          | 0/4789 [00:00<?, ?it/s]2024-12-04 11:15:33 - Fetching items 0-50 of 4789 from portal
# 2024-12-04 11:15:33 - Successfully retrieved 100 items from portal
# 2024-12-04 11:15:33 - Fetching items 50-100 of 4789 from portal
# Retrieving portal items:   4%|▍         | 200/4789 [00:00<00:14, 319.14it/s]2024-12-04 11:15:33 - Successfully retrieved 100 items from portal
# 2024-12-04 11:15:34 - Fetching items 100-150 of 4789 from portal
# Retrieving portal items:   6%|▋         | 300/4789 [00:01<00:18, 240.77it/s]2024-12-04 11:15:34 - Successfully retrieved 100 items from portal
# 2024-12-04 11:15:34 - Fetching items 150-200 of 4789 from portal
# Retrieving portal items:   8%|▊         | 400/4789 [00:01<00:20, 212.59it/s]2024-12-04 11:15:34 - Successfully retrieved 100 items from portal
# 2024-12-04 11:15:35 - Fetching items 200-250 of 4789 from portal
# Retrieving portal items:  10%|█         | 500/4789 [00:02<00:21, 198.54it/s]2024-12-04 11:15:35 - Successfully retrieved 100 items from portal
# 2024-12-04 11:15:35 - Fetching items 250-300 of 4789 from portal
# Retrieving portal items:  13%|█▎        | 600/4789 [00:02<00:21, 191.17it/s]2024-12-04 11:15:36 - Successfully retrieved 100 items from portal
# 2024-12-04 11:15:36 - Fetching items 300-350 of 4789 from portal
# Retrieving portal items:  15%|█▍        | 700/4789 [00:03<00:21, 186.99it/s]2024-12-04 11:15:36 - Successfully retrieved 100 items from portal
# 2024-12-04 11:15:37 - Fetching items 350-400 of 4789 from portal
# Retrieving portal items:  17%|█▋        | 800/4789 [00:03<00:21, 184.18it/s]2024-12-04 11:15:37 - Successfully retrieved 100 items from portal
# 2024-12-04 11:15:37 - Fetching items 400-450 of 4789 from portal
# Retrieving portal items:  19%|█▉        | 900/4789 [00:04<00:21, 181.46it/s]2024-12-04 11:15:37 - Successfully retrieved 100 items from portal
# 2024-12-04 11:15:38 - Fetching items 450-500 of 4789 from portal
# Retrieving portal items:  21%|██        | 1000/4789 [00:05<00:21, 178.38it/s]2024-12-04 11:15:38 - Successfully retrieved 100 items from portal
# 2024-12-04 11:15:38 - Fetching items 500-550 of 4789 from portal
# Retrieving portal items:  23%|██▎       | 1100/4789 [00:05<00:20, 176.96it/s]2024-12-04 11:15:38 - Successfully retrieved 100 items from portal
# 2024-12-04 11:15
- Successfully retrieved 100 items from portal
# 2024-12-04 11:17:48 - Fetching items 4700-4750 of 4789 from portal
# Retrieving portal items: 9500it [00:52, 177.85it/s]2024-12-04 11:17:48 - Successfully retrieved 100 items from portal
# 2024-12-04 11:17:48 - Fetching items 4750-4800 of 4789 from portal
# Retrieving portal items: 9600it [00:53, 177.99it/s]2024-12-04 11:17:48 - Successfully retrieved 100 items from portal
# Retrieving portal items: 9600it [00:53, 179.81it/s]
# 2024-12-04 11:17:48 - Completed retrieval for portal. Got 9600 items
# Processing portal titles: 100%|██████████| 9600/9600 [00:00<00:00, 2056136.36it/s]
# 2024-12-04 11:17:48 - Processing search library for duplicates...
# Retrieving search items:   0%|          | 0/1316 [00:00<?, ?it/s]2024-12-04 11:17:48 - Fetching items 0-50 of 1316 from search
# 2024-12-04 11:17:48 - Successfully retrieved 100 items from search
# 2024-12-04 11:17:49 - Fetching items 50-100 of 1316 from search
# Retrieving search items:  15%|█▌        | 200/1316 [00:00<00:03, 352.02it/s]2024-12-04 11:17:49 - Successfully retrieved 100 items from search
# 2024-12-04 11:17:49 - Fetching items 100-150 of 1316 from search
# Retrieving search items:  23%|██▎       | 300/1316 [00:01<00:03, 254.52it/s]2024-12-04 11:17:49 - Successfully retrieved 100 items from search
# 2024-12-04 11:17:50 - Fetching items 150-200 of 1316 from search
# Retrieving search items:  30%|███       | 400/1316 [00:01<00:04, 222.10it/s]2024-12-04 11:17:50 - Successfully retrieved 100 items from search
# 2024-12-04 11:17:50 - Fetching items 200-250 of 1316 from search
# Retrieving search items:  38%|███▊      | 500/1316 [00:02<00:03, 206.33it/s]2024-12-04 11:17:50 - Successfully retrieved 100 items from search
# 2024-12-04 11:17:51 - Fetching items 250-300 of 1316 from search
# Retrieving search items:  46%|████▌     | 600/1316 [00:02<00:03, 197.33it/s]2024-12-04 11:17:51 - Successfully retrieved 100 items from search
# 2024-12-04 11:17:52 - Fetching items 300-350 of 1316 from search
# Retrieving search items:  53%|█████▎    | 700/1316 [00:03<00:03, 192.38it/s]2024-12-04 11:17:52 - Successfully retrieved 100 items from search
# 2024-12-04 11:17:52 - Fetching items 350-400 of 1316 from search
# Retrieving search items:  61%|██████    | 800/1316 [00:03<00:02, 188.61it/s]2024-12-04 11:17:52 - Successfully retrieved 100 items from search
# 2024-12-04 11:17:53 - Fetching items 400-450 of 1316 from search
# Retrieving search items:  68%|██████▊   | 900/1316 [00:04<00:02, 186.85it/s]2024-12-04 11:17:53 - Successfully retrieved 100 items from search
# 2024-12-04 11:17:53 - Fetching items 450-500 of 1316 from search
# Retrieving search items:  76%|███████▌  | 1000/1316 [00:04<00:01, 185.03it/s]2024-12-04 11:17:53 - Successfully retrieved 100 items from search
# 2024-12-04 11:17:54 - Fetching items 500-550 of 1316 from search
# Retrieving search items:  84%|████████▎ | 1100/1316 [00:05<00:01, 183.78it/s]2024-12-04 11:17:54 - Successfully retrieved 100 items from search
# 2024-12-04 11:17:54 - Fetching items 550-600 of 1316 from search
# Retrieving search items:  91%|█████████ | 1200/1316 [00:06<00:00, 183.74it/s]2024-12-04 11:17:54 - Successfully retrieved 100 items from search
# 2024-12-04 11:17:55 - Fetching items 600-650 of 1316 from search
# Retrieving search items:  99%|█████████▉| 1300/1316 [00:06<00:00, 183.53it/s]2024-12-04 11:17:55 - Successfully retrieved 100 items from search
# 2024-12-04 11:17:55 - Fetching items 650-700 of 1316 from search
# Retrieving search items: 1400it [00:07, 183.28it/s]                          2024-12-04 11:17:55 - Successfully retrieved 100 items from search
# 2024-12-04 11:17:56 - Fetching items 700-750 of 1316 from search
# Retrieving search items: 1500it [00:07, 183.31it/s]2024-12-04 11:17:56 - Successfully retrieved 100 items from search
# 2024-12-04 11:17:56 - Fetching items 750-800 of 1316 from search
# Retrieving search items: 1600it [00:08, 182.78it/s]2024-12-04 11:17:57 - Successfully retrieved 100 items from search
# 2024-12-04 11:17:57 - Fetching items 800-850 of 1316 from search
# Retrieving search items: 1700it [00:08, 183.09it/s]2024-12-04 11:17:57 - Successfully retrieved 100 items from search
# 2024-12-04 11:17:58 - Fetching items 850-900 of 1316 from search
# Retrieving search items: 1800it [00:09, 182.51it/s]2024-12-04 11:17:58 - Successfully retrieved 100 items from search
# 2024-12-04 11:17:58 - Fetching items 900-950 of 1316 from search
# Retrieving search items: 1900it [00:09, 182.77it/s]2024-12-04 11:17:58 - Successfully retrieved 100 items from search
# 2024-12-04 11:17:59 - Fetching items 950-1000 of 1316 from search
# Retrieving search items: 2000it [00:10, 182.72it/s]2024-12-04 11:17:59 - Successfully retrieved 100 items from search
# 2024-12-04 11:17:59 - Fetching items 1000-1050 of 1316 from search
# Retrieving search items: 2100it [00:10, 182.76it/s]2024-12-04 11:17:59 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:00 - Fetching items 1050-1100 of 1316 from search
# Retrieving search items: 2200it [00:11, 183.10it/s]2024-12-04 11:18:00 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:00 - Fetching items 1100-1150 of 1316 from search
# Retrieving search items: 2300it [00:12, 182.33it/s]2024-12-04 11:18:00 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:01 - Fetching items 1150-1200 of 1316 from search
# Retrieving search items: 2400it [00:12, 182.01it/s]2024-12-04 11:18:01 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:01 - Fetching items 1200-1250 of 1316 from search
# Retrieving search items: 2500it [00:13, 182.22it/s]2024-12-04 11:18:01 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:02 - Fetching items 1250-1300 of 1316 from search
# Retrieving search items: 2600it [00:13, 182.43it/s]2024-12-04 11:18:02 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:02 - Fetching items 1300-1350 of 1316 from search
# Retrieving search items: 2700it [00:14, 181.47it/s]2024-12-04 11:18:03 - Successfully retrieved 100 items from search
# Retrieving search items: 2700it [00:14, 189.03it/s]
# 2024-12-04 11:18:03 - Completed retrieval for search. Got 2700 items
# Processing search titles: 100%|██████████| 2700/2700 [00:00<00:00, 219265.43it/s]
# 2024-12-04 11:18:03 - Found 1 duplicate titles
# 2024-12-04 11:18:03 - Creating Venn diagram...
# Processing duplicates: 100%|██████████| 1/1 [00:00<00:00, 34663.67it/s]
# 2024-12-04 11:18:03 - Starting integrated analysis...
# 2024-12-04 11:18:03 - Processing search library...
# Analysis Summary:
# Portal Library Items: 100
# Search Library Items: 70
# Duplicate Items: 1
# Retrieving search items:   0%|          | 0/1316 [00:00<?, ?it/s]2024-12-04 11:18:03 - Fetching items 0-50 of 1316 from search
# 2024-12-04 11:18:03 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:03 - Fetching items 50-100 of 1316 from search
# Retrieving search items:  15%|█▌        | 200/1316 [00:00<00:03, 339.83it/s]2024-12-04 11:18:03 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:04 - Fetching items 100-150 of 1316 from search
# Retrieving search items:  23%|██▎       | 300/1316 [00:01<00:04, 247.47it/s]2024-12-04 11:18:04 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:04 - Fetching items 150-200 of 1316 from search
# Retrieving search items:  30%|███       | 400/1316 [00:01<00:04, 219.70it/s]2024-12-04 11:18:04 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:05 - Fetching items 200-250 of 1316 from search
# Retrieving search items:  38%|███▊      | 500/1316 [00:02<00:03, 205.55it/s]2024-12-04 11:18:05 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:05 - Fetching items 250-300 of 1316 from search
# Retrieving search items:  46%|████▌     | 600/1316 [00:02<00:03, 190.06it/s]2024-12-04 11:18:05 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:06 - Fetching items 300-350 of 1316 from search
# Retrieving search items:  53%|█████▎    | 700/1316 [00:03<00:03, 188.10it/s]2024-12-04 11:18:06 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:06 - Fetching items 350-400 of 1316 from search
# Retrieving search items:  61%|██████    | 800/1316 [00:03<00:02, 186.81it/s]2024-12-04 11:18:07 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:07 - Fetching items 400-450 of 1316 from search
# Retrieving search items:  68%|██████▊   | 900/1316 [00:04<00:02, 185.07it/s]2024-12-04 11:18:07 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:08 - Fetching items 450-500 of 1316 from search
# Retrieving search items:  76%|███████▌  | 1000/1316 [00:05<00:01, 183.51it/s]2024-12-04 11:18:08 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:08 - Fetching items 500-550 of 1316 from search
# Retrieving search items:  84%|████████▎ | 1100/1316 [00:05<00:01, 182.63it/s]2024-12-04 11:18:08 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:09 - Fetching items 550-600 of 1316 from search
# Retrieving search items:  91%|█████████ | 1200/1316 [00:06<00:00, 182.97it/s]2024-12-04 11:18:09 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:09 - Fetching items 600-650 of 1316 from search
# Retrieving search items:  99%|█████████▉| 1300/1316 [00:06<00:00, 183.30it/s]2024-12-04 11:18:09 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:10 - Fetching items 650-700 of 1316 from search
# Retrieving search items: 1400it [00:07, 183.66it/s]                          2024-12-04 11:18:10 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:10 - Fetching items 700-750 of 1316 from search
# Retrieving search items: 1500it [00:07, 183.85it/s]2024-12-04 11:18:10 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:11 - Fetching items 750-800 of 1316 from search
# Retrieving search items: 1600it [00:08, 184.07it/s]2024-12-04 11:18:11 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:11 - Fetching items 800-850 of 1316 from search
# Retrieving search items: 1700it [00:08, 183.85it/s]2024-12-04 11:18:11 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:12 - Fetching items 850-900 of 1316 from search
# Retrieving search items: 1800it [00:09, 183.84it/s]2024-12-04 11:18:12 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:12 - Fetching items 900-950 of 1316 from search
# Retrieving search items: 1900it [00:09, 183.45it/s]2024-12-04 11:18:13 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:13 - Fetching items 950-1000 of 1316 from search
# Retrieving search items: 2000it [00:10, 183.04it/s]2024-12-04 11:18:13 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:14 - Fetching items 1000-1050 of 1316 from search
# Retrieving search items: 2100it [00:11, 183.20it/s]2024-12-04 11:18:14 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:14 - Fetching items 1050-1100 of 1316 from search
# Retrieving search items: 2200it [00:11, 183.25it/s]2024-12-04 11:18:14 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:15 - Fetching items 1100-1150 of 1316 from search
# Retrieving search items: 2300it [00:12, 183.04it/s]2024-12-04 11:18:15 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:15 - Fetching items 1150-1200 of 1316 from search
# Retrieving search items: 2400it [00:12, 182.91it/s]2024-12-04 11:18:15 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:16 - Fetching items 1200-1250 of 1316 from search
# Retrieving search items: 2500it [00:13, 183.01it/s]2024-12-04 11:18:16 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:16 - Fetching items 1250-1300 of 1316 from search
# Retrieving search items: 2600it [00:13, 182.99it/s]2024-12-04 11:18:16 - Successfully retrieved 100 items from search
# 2024-12-04 11:18:17 - Fetching items 1300-1350 of 1316 from search
# Retrieving search items: 2700it [00:14, 183.01it/s]2024-12-04 11:18:17 - Successfully retrieved 100 items from search
# Retrieving search items: 2700it [00:14, 188.67it/s]
# 2024-12-04 11:18:17 - Completed retrieval for search. Got 2700 items
# Matching items: 100%|██████████| 2700/2700 [00:00<00:00, 2165319.46it/s]
# XML Analysis Summary:
#
# Search Library:
# Total Zotero Items: 2700
# Total Deduplicated XML Items: 0
# Total Duplicate XML Items: 0
# Matched Items: 0
#
# Analysis completed at: 2024-12-04 11:18:17
# Total duration: 0:03:56.278361
